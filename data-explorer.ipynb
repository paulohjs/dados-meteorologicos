# %%
import pandas as pd
data = pd.read_parquet('weather_data.parquet')

# data.set_index()

print(data)
# Out:
#                                  city                time  temp  rhum  prcp  \
# 0                  Uberlândia, Brasil 2021-01-01 20:00:00  24.1  65.0   NaN
# 1                  Uberlândia, Brasil 2021-01-01 21:00:00  24.0  67.0   0.4
# 2                  Uberlândia, Brasil 2021-01-01 22:00:00  23.2  69.0   0.7
# 3                  Uberlândia, Brasil 2021-01-01 23:00:00  22.5  78.0   0.9
# 4                  Uberlândia, Brasil 2021-01-02 00:00:00  22.5  70.0   0.5
# ...                               ...                 ...   ...   ...   ...
# 373544               Araguari, Brasil 2024-11-17 16:00:00  25.2  65.0   0.2
# 373545              Ituiutaba, Brasil 2024-11-17 16:00:00  28.0  69.0   0.2
# 373546         Patos de Minas, Brasil 2024-11-17 16:00:00  25.1  70.0   NaN
# 373547          Montes Claros, Brasil 2024-11-17 16:00:00  26.2  64.0   0.0
# 373548  Conceição das Alagoas, Brasil 2024-11-17 16:00:00  26.0  73.0   1.1
#
#         wspd
# 0        4.7
# 1        3.2
# ...

# %%
print(data['city'].unique())
# Out:
# ['Uberlândia, Brasil' 'Uberaba, Brasil' 'Araguari, Brasil'
#  'Ituiutaba, Brasil' 'Patos de Minas, Brasil' 'Montes Claros, Brasil'
#  'Conceição das Alagoas, Brasil' 'Centralina, Brasil' 'Paracatu, Brasil'
#  'Patrocínio, Brasil' 'Pedra do Indaiá, Brasil']

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 373549 entries, 0 to 373548
# Data columns (total 6 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   city    373549 non-null  object
#  1   time    373549 non-null  datetime64[ns]
#  2   temp    372385 non-null  float64
#  3   rhum    372385 non-null  float64
#  4   prcp    337716 non-null  float64
#  5   wspd    372385 non-null  float64
# dtypes: datetime64[ns](1), float64(4), object(1)
# memory usage: 17.1+ MB

# %%
#data = data.dropna()

print(data['time'].max())

data.plot(x='time', y='temp')
# Out:
# 2024-11-17 16:00:00
# <Axes: xlabel='time'>
